# %%
import requests
import pandas as pd
import json

# %%
zipcodes = ["97107", "97212"]
terms = "restaurant"
offset = "0"
url = ("https://api.yelp.com/v3/businesses/search?location=" + zipcodes[0] + "&term=" + terms + "&limit=50&offset=" + offset)
print(url)
# Out:
# https://api.yelp.com/v3/businesses/search?location=97107&term=restaurant&limit=50&offset=0

# %%
zipcodes_df = pd.read_csv("data/usa_zipcode_of_or-1554j.csv")
zipcodes_df['zipcodes'] = zipcodes_df['zipcodes'].apply(str)
zipcodes = zipcodes_df["zipcodes"].to_list()
zipcodes[0]
# Out:
# '97810'

# %%
# create empty dataframe for appending new yelp food data
oregon_restaurant_data = []
# import all oregon zipcodes dataframe
# zipcodes_df = pd.read_csv("usa_zipcode_of_or-1554j.csv")
# get zipcodes alone to series/list and save as variable
# zipcodes = zipcodes_df["zipcodes"].to_list()
# create list of all terms to search
terms = ["restaurant", "bar", "bakery", "cafe", "deli", "grocery", "eatery", "winery", "lunch", "dinner", "breakfast", "brunch", "buffet"]


# add the following to terms list?? Eatery, Winery, Lunch, Dinner, Brunch, Breakfast, BUFFET, cafeteria
# create offset series
offset = ["0", "50", "100", "150", "200", "250", "300", "350", "400", "500", "550", "600", "650", "700", "750", "800", "850", "900", "950"]
#offset = 0
for i in range(len(zipcodes)):
    url1 = ("https://api.yelp.com/v3/businesses/search?location=" + zipcodes[i])
    for i in range(len(terms)):
        url2 = (url1 + "&term=" + terms[i])
        for i in range(len(offset)):
            url = (url2 + "&limit=50&offset=" + offset[i])
            payload={}
            headers = {
              'Authorization': 'Bearer IDhnPDd7iN8jUqd4cjutgzQwQmzWiGLxZ32w9oZHorJFnqJen83TyUVT91k0uOedGtxZSicxs-IQTRBLTz8dHtR_hJ7UobxijVvGFbbcVlBi1V-8wBNruUEa7ahNY3Yx'
            }
            response = requests.request("GET", url, headers=headers, data=payload)
            data = response.text
            oregon_restaurant = json.loads(data)
            if len(oregon_restaurant['businesses']) != 0:

                for i in range(len(oregon_restaurant["businesses"])):
                    business_status = oregon_restaurant["businesses"][i]["is_closed"] # proved that this works
                    name = oregon_restaurant["businesses"][i]["name"]
                    address = oregon_restaurant["businesses"][i]["location"]["address1"]
                    city = oregon_restaurant["businesses"][i]["location"]["city"]
                    state = oregon_restaurant["businesses"][i]["location"]["state"]
                    zip_code = oregon_restaurant["businesses"][i]["location"]["zip_code"]
                    rating = oregon_restaurant["businesses"][i]["rating"]

                    oregon_restaurant_data.append({"Business Status": business_status,
                                                       "Address": address,
                                                       "City": city,
                                                       "State": state,
                                                       "Zip": zip_code,
                                                       "Business Name": name,
                                                       "Star Rating": rating})
            else:
                # print(zipcodes[i], terms[i], "is done")
                print("next")
                # don't know what to do here if there is no longer a response content to get it to trigger the next term iteration
# Out:
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# next
# ...

# %%
oregon_restaurant_data
# Out:
# [{'Business Status': False,
#   'Address': '327 E Main St',
#   'City': 'Athena',
#   'State': 'OR',
#   'Zip': '97813',
#   'Business Name': 'Doubletree Restaurant & Lounge',
#   'Star Rating': 4.0},
#  {'Business Status': False,
#   'Address': '106 Main St',
#   'City': 'Weston',
#   'State': 'OR',
#   'Zip': '97886',
#   'Business Name': 'Upper Crust Weston',
#   'Star Rating': 5.0},
#  {'Business Status': False,
#   'Address': '101 E Main St',
#   'City': 'Weston',
#   'State': 'OR',
#   'Zip': '97886',
#   'Business Name': 'Central Station',
#   'Star Rating': 4.5},
#  {'Business Status': False,
#   'Address': '201 E Main St',
#   'City': 'Weston',
#   'State': 'OR',
#   'Zip': '97886',
#   'Business Name': 'Long Branch Cafe & Saloon',
#   'Star Rating': 3.5},
#  {'Business Status': False,
#   'Address': 'Main St',
#   'City': 'Athena',
#   'State': 'OR',
#   'Zip': '97813',
#   'Business Name': 'Taco Bus',
#   'Star Rating': 5.0},
#  {'Business Status': False,
# ...

# %%
yelp_all_food_df = pd.DataFrame(oregon_restaurant_data)
yelp_all_food_df
# Out:
#        Business Status                        Address          City State  \
# 0                False                  327 E Main St        Athena    OR
# 1                False                    106 Main St        Weston    OR
# 2                False                  101 E Main St        Weston    OR
# 3                False                  201 E Main St        Weston    OR
# 4                False                        Main St        Athena    OR
# ...                ...                            ...           ...   ...
# 31635            False               3424 Pacific Ave  Forest Grove    OR
# 31636            False              1315 NW 185th Ave     Beaverton    OR
# 31637            False  10840 SW Tualatin Sherwood Rd      Tualatin    OR
# 31638            False   18295 SW Tualatin Valley Hwy         Aloha    OR
# 31639            False    5121 SE Tualatin Valley Hwy     Hillsboro    OR
#
#          Zip                   Business Name  Star Rating
# ...

# %%
output_data_file = "yelp_all_food_extra_terms.csv"
# Export the City_Data into a CSV.
yelp_all_food_df.to_csv(output_data_file, index=False)

# %%
yelp_data_df = pd.read_csv("data/yelp_all_food_extra_terms.csv")
yelp_data_df.head()
# Out:
#    Business Status        Address    City State    Zip  \
# 0            False  327 E Main St  Athena    OR  97813
# 1            False    106 Main St  Weston    OR  97886
# 2            False  101 E Main St  Weston    OR  97886
# 3            False  201 E Main St  Weston    OR  97886
# 4            False        Main St  Athena    OR  97813
#
#                     Business Name  Star Rating
# 0  Doubletree Restaurant & Lounge          4.0
# 1              Upper Crust Weston          5.0
# 2                 Central Station          4.5
# 3       Long Branch Cafe & Saloon          3.5
# 4                        Taco Bus          5.0

# %%
all_oregon_restaurant_df = yelp_data_df.sort_values(by=['Business Name'])
all_oregon_restaurant_df
# Out:
#        Business Status             Address      City State    Zip  \
# 3546             False  8249 W Overland Rd     Boise    ID  83709
# 4682             False  8249 W Overland Rd     Boise    ID  83709
# 29801            False       148 Merlin Rd    Merlin    OR  97532
# 6687             False       148 Merlin Rd    Merlin    OR  97532
# 6080             False       148 Merlin Rd    Merlin    OR  97532
# ...                ...                 ...       ...   ...    ...
# 30592            False       29 W First St  Coquille    OR  97423
# 4889             False       29 W First St  Coquille    OR  97423
# 6284             False       29 W First St  Coquille    OR  97423
# 30767            False       29 W First St  Coquille    OR  97423
# 5859             False       29 W First St  Coquille    OR  97423
#
#                                            Business Name  Star Rating
# 3546   #1 Mongolian BBQ - Best Stir Fried Noodles In ...          3.5
# ...

# %%
new_column_order = ["Business Name", "Address", "City", "State", "Zip", "Business Status", "Star Rating"]
all_oregon_restaurant_df = all_oregon_restaurant_df[new_column_order]
print("All Oregon Food Establishment Yelp Data")
all_oregon_restaurant_df.head()
# Out:
# All Oregon Food Establishment Yelp Data
#                                            Business Name             Address  \
# 3546   #1 Mongolian BBQ - Best Stir Fried Noodles In ...  8249 W Overland Rd
# 4682   #1 Mongolian BBQ - Best Stir Fried Noodles In ...  8249 W Overland Rd
# 29801                          'lil Pantry Market & Deli       148 Merlin Rd
# 6687                           'lil Pantry Market & Deli       148 Merlin Rd
# 6080                           'lil Pantry Market & Deli       148 Merlin Rd
#
#          City State    Zip  Business Status  Star Rating
# 3546    Boise    ID  83709            False          3.5
# 4682    Boise    ID  83709            False          3.5
# 29801  Merlin    OR  97532            False          2.5
# 6687   Merlin    OR  97532            False          2.5
# 6080   Merlin    OR  97532            False          2.5

# %%
all_oregon_restaurant_df = all_oregon_restaurant_df[all_oregon_restaurant_df["State"] == "OR"]
print("All Yelp Food Data for Oregon")
all_oregon_restaurant_df
# Out:
# All Yelp Food Data for Oregon
#                    Business Name        Address      City State    Zip  \
# 29801  'lil Pantry Market & Deli  148 Merlin Rd    Merlin    OR  97532
# 6687   'lil Pantry Market & Deli  148 Merlin Rd    Merlin    OR  97532
# 6080   'lil Pantry Market & Deli  148 Merlin Rd    Merlin    OR  97532
# 29729  'lil Pantry Market & Deli  148 Merlin Rd    Merlin    OR  97532
# 29558  'lil Pantry Market & Deli  148 Merlin Rd    Merlin    OR  97532
# ...                          ...            ...       ...   ...    ...
# 30592          uncle randys cafe  29 W First St  Coquille    OR  97423
# 4889           uncle randys cafe  29 W First St  Coquille    OR  97423
# 6284           uncle randys cafe  29 W First St  Coquille    OR  97423
# 30767          uncle randys cafe  29 W First St  Coquille    OR  97423
# 5859           uncle randys cafe  29 W First St  Coquille    OR  97423
#
#        Business Status  Star Rating
# 29801            False          2.5
# ...

# %%
Address = []
for index in range(len(all_oregon_restaurant_df)):
    address = f'{all_oregon_restaurant_df.iloc[index, 1]} , {all_oregon_restaurant_df.iloc[index, 2]}, {all_oregon_restaurant_df.iloc[index, 3]} {all_oregon_restaurant_df.iloc[index, 4]} ,  United States'
    Address.append(address)
   
len(Address)
# Out:
# 25953

# %%
all_oregon_restaurant_df['Address'] = Address
new_column_order = ["Business Name", "Address", "Business Status", "Star Rating"]
all_oregon_restaurant_df = all_oregon_restaurant_df[new_column_order]
print(all_oregon_restaurant_df["Business Name"].count())
all_oregon_restaurant_df.head(20)
# Out:
# 25953
#                    Business Name  \
# 29801  'lil Pantry Market & Deli
# 6687   'lil Pantry Market & Deli
# 6080   'lil Pantry Market & Deli
# 29729  'lil Pantry Market & Deli
# 29558  'lil Pantry Market & Deli
# 5482   'lil Pantry Market & Deli
# 5113   'lil Pantry Market & Deli
# 4938             101 Bar & Grill
# 6295             101 Bar & Grill
# 5187             101 Bar & Grill
# 11466             101 Taco Truck
# 26344         12th Street Market
# 9915          12th Street Market
# 16124         12th Street Market
# 26023     12th Street Pub & Grub
# 9439      12th Street Pub & Grub
# 7325      12th Street Pub & Grub
# 15491     12th Street Pub & Grub
# 13292        16 Tons Beer & Wine
# 13718        16 Tons Beer & Wine
#
#                                                  Address  Business Status  \
# 29801  148 Merlin Rd , Merlin, OR 97532 ,  United States            False
# 6687   148 Merlin Rd , Merlin, OR 97532 ,  United States            False
# ...

# %%
all_oregon_restaurant_df.drop_duplicates(subset=['Address'], keep='first', inplace=True)
all_oregon_restaurant_df
# Out:
# /var/folders/0g/0f8bfz6d47x6v12s0j396t4w0000gn/T/ipykernel_12135/1755518827.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_oregon_restaurant_df.drop_duplicates(subset=['Address'], keep='first', inplace=True)
#                    Business Name  \
# 29801  'lil Pantry Market & Deli
# 4938             101 Bar & Grill
# 11466             101 Taco Truck
# 26344         12th Street Market
# 26023     12th Street Pub & Grub
# ...                          ...
# 27990          harvester taproom
# 20032                lil' pantry
# 31432  the old spaghetti factory
# 8255         ticket to play cafe
# 30592          uncle randys cafe
#
#                                                  Address  Business Status  \
# 29801  148 Merlin Rd , Merlin, OR 97532 ,  United States            False
# ...

# %%
all_oregon_restaurant_df["Address"] = all_oregon_restaurant_df["Address"].str.upper()
all_oregon_restaurant_df
# Out:
# /var/folders/0g/0f8bfz6d47x6v12s0j396t4w0000gn/T/ipykernel_12135/3091693650.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_oregon_restaurant_df["Address"] = all_oregon_restaurant_df["Address"].str.upper()
#                    Business Name  \
# 29801  'lil Pantry Market & Deli
# 4938             101 Bar & Grill
# 11466             101 Taco Truck
# 26344         12th Street Market
# 26023     12th Street Pub & Grub
# ...                          ...
# 27990          harvester taproom
# 20032                lil' pantry
# 31432  the old spaghetti factory
# 8255         ticket to play cafe
# 30592          uncle randys cafe
#
#                                                  Address  Business Status  \
# ...

# %%
output_data_file = "final_oregon_restaurant_yelp_data_extra_terms.csv"
# Export the City_Data into a CSV.
all_oregon_restaurant_df.to_csv(output_data_file, index=False)

# %%
yelp_data_df1 = pd.read_csv("data/final_oregon_restaurant_yelp_data.csv")
yelp_data_df1.head()
# Out:
#                         Business Name  \
# 0           'lil Pantry Market & Deli
# 1                   007 Hookah Lounge
# 2  10 Barrel Brewing - West Side Bend
# 3          10 Barrel Brewing Portland
# 4                     101 Bar & Grill
#
#                                              Address  Business Status  \
# 0  148 MERLIN RD , MERLIN, OR 97532 ,  UNITED STATES            False
# 1  2524 SE DIVISION ST , PORTLAND, OR 97202 ,  UN...            False
# 2  1135 NW GALVESTON AVE , BEND, OR 97701 ,  UNIT...            False
# 3  1411 NW FLANDERS ST , PORTLAND, OR 97209 ,  UN...            False
# 4  98141 W BENHAM LN , BROOKINGS, OR 97415 ,  UNI...            False
#
#    Star Rating
# 0          2.5
# 1          4.5
# 2          4.0
# 3          4.0
# 4          3.5

# %%
all_or_yelp = all_oregon_restaurant_df.append(yelp_data_df1, ignore_index=True)
all_or_yelp
# Out:
# /var/folders/0g/0f8bfz6d47x6v12s0j396t4w0000gn/T/ipykernel_12135/1580064499.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_or_yelp = all_oregon_restaurant_df.append(yelp_data_df1, ignore_index=True)
#                    Business Name  \
# 0      'lil Pantry Market & Deli
# 1                101 Bar & Grill
# 2                 101 Taco Truck
# 3             12th Street Market
# 4         12th Street Pub & Grub
# ...                          ...
# 15875              richards deli
# 15876                     sousòl
# 15877  the old spaghetti factory
# 15878        ticket to play cafe
# 15879          uncle randys cafe
#
#                                                  Address  Business Status  \
# 0      148 MERLIN RD , MERLIN, OR 97532 ,  UNITED STATES            False
# 1      98141 W BENHAM LN , BROOKINGS, OR 97415 ,  UNI...            False
# ...

# %%
all_or_yelp.drop_duplicates(subset=['Address'], keep='first', inplace=True)
all_or_yelp
# Out:
#                    Business Name  \
# 0      'lil Pantry Market & Deli
# 1                101 Bar & Grill
# 2                 101 Taco Truck
# 3             12th Street Market
# 4         12th Street Pub & Grub
# ...                          ...
# 15870                    fuAsian
# 15872        las delicias bakery
# 15874                      p:ear
# 15875              richards deli
# 15876                     sousòl
#
#                                                  Address  Business Status  \
# 0      148 MERLIN RD , MERLIN, OR 97532 ,  UNITED STATES            False
# 1      98141 W BENHAM LN , BROOKINGS, OR 97415 ,  UNI...            False
# 2      790 N BAYSHORE DR , COOS BAY, OR 97420 ,  UNIT...            False
# 3      1695 12TH ST SE , SALEM, OR 97302 ,  UNITED ST...            False
# 4      2795 12TH ST SE , SALEM, OR 97302 ,  UNITED ST...            False
# ...                                                  ...              ...
# ...

# %%
output_data_file = "final_oregon_restaurant_yelp_data_combined.csv"
# Export the City_Data into a CSV.
all_or_yelp.to_csv(output_data_file, index=False)
