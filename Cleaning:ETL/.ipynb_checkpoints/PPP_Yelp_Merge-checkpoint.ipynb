# %%
import pandas as pd
import numpy as np

# %%
all_or_food_ppp = pd.read_csv("data/all_oregon_restaurant_ppp_data.csv")
or_yelp_food_df = pd.read_csv("data/final_oregon_restaurant_yelp_data_combined.csv")
oregon_mail_df = pd.read_csv("data/final_oregon_allbiz_mailling_data.csv")
all_or_food_ppp
# Out:
#                Business Name  \
# 0                        NaN
# 1     (THE) PANDA RESTAURANT
# 2     (THE) PANDA RESTAURANT
# 3     (THE) PANDA RESTAURANT
# 4               1-2-3 YO LLC
# ...                      ...
# 7304               ZNE CORP.
# 7305   ZOLA'S PIZZERIA, INC.
# 7306          ZONA ROSA INC.
# 7307                ZOOK LLC
# 7308            ZUM WHOL INC
#
#                                                 Address Loan Amount  \
# 0                                                   NaN         sum
# 1     555 N MAIN ST. , PRINEVILLE, OR 97754 ,  UNITE...     17000.0
# 2     2118 LANCASTER DRIVE NORTHEAST,SUITE 110 , SAL...     18100.0
# 3     224 NORTHWEST 1ST AVENUE, OREGON , CANBY, OR 9...     25500.0
# 4     3962 SE HAWTHORNE BLVD , PORTLAND, OR 97214 , ...    131453.0
# ...                                                 ...         ...
# 7304  4066 MOOSE RUN DR SW , ALBANY, OR 97321 ,  UNI...    166010.0
# ...

# %%
# dataframe for machine learning. It is only the ppp data, using jobs/funding amount and ratio, we can determine if it will be open or closed
ppp_yelp_left_ppp = all_or_food_ppp.merge(or_yelp_food_df,  how='left', on=['Address'])
ppp_yelp_left_ppp["New Business Status"] = ""
ppp_yelp_left_ppp['Business Status'] = ppp_yelp_left_ppp['Business Status'].map({False: 'False'})
for index in range(len(ppp_yelp_left_ppp)):
    if ppp_yelp_left_ppp["Business Status"][index] == "False":
        ppp_yelp_left_ppp["New Business Status"][index] = "Open"
    else:
        ppp_yelp_left_ppp["New Business Status"][index] = "Closed"
ppp_yelp_left_ppp
# Out:
# /var/folders/0g/0f8bfz6d47x6v12s0j396t4w0000gn/T/ipykernel_12302/902890659.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ppp_yelp_left_ppp["New Business Status"][index] = "Closed"
# /var/folders/0g/0f8bfz6d47x6v12s0j396t4w0000gn/T/ipykernel_12302/902890659.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ppp_yelp_left_ppp["New Business Status"][index] = "Open"
#              Business Name_x  \
# 0                        NaN
# 1     (THE) PANDA RESTAURANT
# 2     (THE) PANDA RESTAURANT
# 3     (THE) PANDA RESTAURANT
# 4               1-2-3 YO LLC
# ...                      ...
# ...

# %%
ppp_yelp_left_ppp = ppp_yelp_left_ppp.drop([0], axis=0)
ppp_yelp_left_ppp
# Out:
#              Business Name_x  \
# 1     (THE) PANDA RESTAURANT
# 2     (THE) PANDA RESTAURANT
# 3     (THE) PANDA RESTAURANT
# 4               1-2-3 YO LLC
# 5           10 SPEED HEIGHTS
# ...                      ...
# 7304               ZNE CORP.
# 7305   ZOLA'S PIZZERIA, INC.
# 7306          ZONA ROSA INC.
# 7307                ZOOK LLC
# 7308            ZUM WHOL INC
#
#                                                 Address Loan Amount  \
# 1     555 N MAIN ST. , PRINEVILLE, OR 97754 ,  UNITE...     17000.0
# 2     2118 LANCASTER DRIVE NORTHEAST,SUITE 110 , SAL...     18100.0
# 3     224 NORTHWEST 1ST AVENUE, OREGON , CANBY, OR 9...     25500.0
# 4     3962 SE HAWTHORNE BLVD , PORTLAND, OR 97214 , ...    131453.0
# 5     1412 13TH ST STE 300 , HOOD RIVER, OR 97031 , ...     15284.0
# ...                                                 ...         ...
# 7304  4066 MOOSE RUN DR SW , ALBANY, OR 97321 ,  UNI...    166010.0
# ...

# %%
new_column_order = ["Address", 
                    "Business Name_x", 
                    "Loan Amount", 
                    "Foregiveness Amount", 
                    "Foregiveness Rate", 
                    "Approval Date", 
                    "New Business Status", 
                    "Jobs"]
ppp_yelp_left_ppp = ppp_yelp_left_ppp[new_column_order]
ppp_yelp_left_ppp = ppp_yelp_left_ppp.rename(columns={"Business Name_x":"Business Name (PPP)",
                                                            "BorrowerZip":"Zip", 
                                                            "New Business Status":"Business Status"})
ppp_yelp_left_ppp
# Out:
#                                                 Address  \
# 1     555 N MAIN ST. , PRINEVILLE, OR 97754 ,  UNITE...
# 2     2118 LANCASTER DRIVE NORTHEAST,SUITE 110 , SAL...
# 3     224 NORTHWEST 1ST AVENUE, OREGON , CANBY, OR 9...
# 4     3962 SE HAWTHORNE BLVD , PORTLAND, OR 97214 , ...
# 5     1412 13TH ST STE 300 , HOOD RIVER, OR 97031 , ...
# ...                                                 ...
# 7304  4066 MOOSE RUN DR SW , ALBANY, OR 97321 ,  UNI...
# 7305  16362 LOWER HARBOR ROAD , BROOKINGS, OR 97415 ...
# 7306  4835 N ALBINA AV , PORTLAND, OR 97217 ,  UNITE...
# 7307  1220 NW 6TH ST , GRANTS PASS, OR 97526 ,  UNIT...
# 7308  401 NE 28TH AVE , PORTLAND, OR 97232 ,  UNITED...
#
#          Business Name (PPP) Loan Amount Foregiveness Amount  \
# 1     (THE) PANDA RESTAURANT     17000.0             17153.7
# 2     (THE) PANDA RESTAURANT     18100.0            18247.28
# 3     (THE) PANDA RESTAURANT     25500.0            25710.99
# ...

# %%
address = ppp_yelp_left_ppp["Address"].str.split(", ", expand = True)
address
# Out:
#                                               0            1          2  \
# 1                               555 N MAIN ST.    PRINEVILLE  OR 97754
# 2     2118 LANCASTER DRIVE NORTHEAST,SUITE 110         SALEM  OR 97305
# 3                      224 NORTHWEST 1ST AVENUE      OREGON       CANBY
# 4                       3962 SE HAWTHORNE BLVD      PORTLAND  OR 97214
# 5                         1412 13TH ST STE 300    HOOD RIVER  OR 97031
# ...                                         ...          ...        ...
# 7304                      4066 MOOSE RUN DR SW        ALBANY  OR 97321
# 7305                   16362 LOWER HARBOR ROAD     BROOKINGS  OR 97415
# 7306                          4835 N ALBINA AV      PORTLAND  OR 97217
# 7307                            1220 NW 6TH ST   GRANTS PASS  OR 97526
# 7308                           401 NE 28TH AVE      PORTLAND  OR 97232
#
#                    3               4     5
# 1      UNITED STATES            None  None
# ...

# %%
zipcode = address[2].str.split(" ", expand = True)
zipcode
# Out:
#           0      1     2
# 1        OR  97754
# 2        OR  97305
# 3     CANBY   None  None
# 4        OR  97214
# 5        OR  97031
# ...     ...    ...   ...
# 7304     OR  97321
# 7305     OR  97415
# 7306     OR  97217
# 7307     OR  97526
# 7308     OR  97232
#
# [7308 rows x 3 columns]

# %%
# making separate first name column from new data frame
ppp_yelp_left_ppp["Zipcode"]= zipcode[1]
ppp_yelp_left_ppp["City"] = address[1]
ppp_yelp_left_ppp.iloc[2, 8] = '97013'
# making separate last name column from new data frame
ppp_yelp_left_ppp
# Out:
#                                                 Address  \
# 1     555 N MAIN ST. , PRINEVILLE, OR 97754 ,  UNITE...
# 2     2118 LANCASTER DRIVE NORTHEAST,SUITE 110 , SAL...
# 3     224 NORTHWEST 1ST AVENUE, OREGON , CANBY, OR 9...
# 4     3962 SE HAWTHORNE BLVD , PORTLAND, OR 97214 , ...
# 5     1412 13TH ST STE 300 , HOOD RIVER, OR 97031 , ...
# ...                                                 ...
# 7304  4066 MOOSE RUN DR SW , ALBANY, OR 97321 ,  UNI...
# 7305  16362 LOWER HARBOR ROAD , BROOKINGS, OR 97415 ...
# 7306  4835 N ALBINA AV , PORTLAND, OR 97217 ,  UNITE...
# 7307  1220 NW 6TH ST , GRANTS PASS, OR 97526 ,  UNIT...
# 7308  401 NE 28TH AVE , PORTLAND, OR 97232 ,  UNITED...
#
#          Business Name (PPP) Loan Amount Foregiveness Amount  \
# 1     (THE) PANDA RESTAURANT     17000.0             17153.7
# 2     (THE) PANDA RESTAURANT     18100.0            18247.28
# 3     (THE) PANDA RESTAURANT     25500.0            25710.99
# ...

# %%
ppp_yelp_allbiz_df = ppp_yelp_left_ppp.merge(oregon_mail_df,  how='left', on=['Address'])
ppp_yelp_allbiz_df
# Out:
#                                                 Address  \
# 0     555 N MAIN ST. , PRINEVILLE, OR 97754 ,  UNITE...
# 1     2118 LANCASTER DRIVE NORTHEAST,SUITE 110 , SAL...
# 2     224 NORTHWEST 1ST AVENUE, OREGON , CANBY, OR 9...
# 3     3962 SE HAWTHORNE BLVD , PORTLAND, OR 97214 , ...
# 4     1412 13TH ST STE 300 , HOOD RIVER, OR 97031 , ...
# ...                                                 ...
# 8664  4066 MOOSE RUN DR SW , ALBANY, OR 97321 ,  UNI...
# 8665  16362 LOWER HARBOR ROAD , BROOKINGS, OR 97415 ...
# 8666  4835 N ALBINA AV , PORTLAND, OR 97217 ,  UNITE...
# 8667  1220 NW 6TH ST , GRANTS PASS, OR 97526 ,  UNIT...
# 8668  401 NE 28TH AVE , PORTLAND, OR 97232 ,  UNITED...
#
#          Business Name (PPP) Loan Amount Foregiveness Amount  \
# 0     (THE) PANDA RESTAURANT     17000.0             17153.7
# 1     (THE) PANDA RESTAURANT     18100.0            18247.28
# 2     (THE) PANDA RESTAURANT     25500.0            25710.99
# ...

# %%
ppp_yelp_allbiz_df["Business Name"].fillna('Closed', inplace = True)
ppp_yelp_allbiz_df
# Out:
#                                                 Address  \
# 0     555 N MAIN ST. , PRINEVILLE, OR 97754 ,  UNITE...
# 1     2118 LANCASTER DRIVE NORTHEAST,SUITE 110 , SAL...
# 2     224 NORTHWEST 1ST AVENUE, OREGON , CANBY, OR 9...
# 3     3962 SE HAWTHORNE BLVD , PORTLAND, OR 97214 , ...
# 4     1412 13TH ST STE 300 , HOOD RIVER, OR 97031 , ...
# ...                                                 ...
# 8664  4066 MOOSE RUN DR SW , ALBANY, OR 97321 ,  UNI...
# 8665  16362 LOWER HARBOR ROAD , BROOKINGS, OR 97415 ...
# 8666  4835 N ALBINA AV , PORTLAND, OR 97217 ,  UNITE...
# 8667  1220 NW 6TH ST , GRANTS PASS, OR 97526 ,  UNIT...
# 8668  401 NE 28TH AVE , PORTLAND, OR 97232 ,  UNITED...
#
#          Business Name (PPP) Loan Amount Foregiveness Amount  \
# 0     (THE) PANDA RESTAURANT     17000.0             17153.7
# 1     (THE) PANDA RESTAURANT     18100.0            18247.28
# 2     (THE) PANDA RESTAURANT     25500.0            25710.99
# ...

# %%
for index in range(len(ppp_yelp_allbiz_df)):
    if ppp_yelp_allbiz_df["Business Name"][index] != "Closed":
        ppp_yelp_allbiz_df["Business Status"][index] = "Open"

ppp_yelp_allbiz_df
# Out:
# /var/folders/0g/0f8bfz6d47x6v12s0j396t4w0000gn/T/ipykernel_12302/772162786.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ppp_yelp_allbiz_df["Business Status"][index] = "Open"
#                                                 Address  \
# 0     555 N MAIN ST. , PRINEVILLE, OR 97754 ,  UNITE...
# 1     2118 LANCASTER DRIVE NORTHEAST,SUITE 110 , SAL...
# 2     224 NORTHWEST 1ST AVENUE, OREGON , CANBY, OR 9...
# 3     3962 SE HAWTHORNE BLVD , PORTLAND, OR 97214 , ...
# 4     1412 13TH ST STE 300 , HOOD RIVER, OR 97031 , ...
# ...                                                 ...
# 8664  4066 MOOSE RUN DR SW , ALBANY, OR 97321 ,  UNI...
# 8665  16362 LOWER HARBOR ROAD , BROOKINGS, OR 97415 ...
# 8666  4835 N ALBINA AV , PORTLAND, OR 97217 ,  UNITE...
# ...

# %%
new_column_order = ["Address", 
                    "Business Name (PPP)",
                    "Loan Amount", 
                    "Foregiveness Amount", 
                    "Foregiveness Rate", 
                    "Approval Date", 
                    "Business Status",
                    "Jobs",
                    "Zipcode",
                    "City"]
                   
ppp_yelp_allbiz_df = ppp_yelp_allbiz_df[new_column_order]
ppp_yelp_allbiz_df
# Out:
#                                                 Address  \
# 0     555 N MAIN ST. , PRINEVILLE, OR 97754 ,  UNITE...
# 1     2118 LANCASTER DRIVE NORTHEAST,SUITE 110 , SAL...
# 2     224 NORTHWEST 1ST AVENUE, OREGON , CANBY, OR 9...
# 3     3962 SE HAWTHORNE BLVD , PORTLAND, OR 97214 , ...
# 4     1412 13TH ST STE 300 , HOOD RIVER, OR 97031 , ...
# ...                                                 ...
# 8664  4066 MOOSE RUN DR SW , ALBANY, OR 97321 ,  UNI...
# 8665  16362 LOWER HARBOR ROAD , BROOKINGS, OR 97415 ...
# 8666  4835 N ALBINA AV , PORTLAND, OR 97217 ,  UNITE...
# 8667  1220 NW 6TH ST , GRANTS PASS, OR 97526 ,  UNIT...
# 8668  401 NE 28TH AVE , PORTLAND, OR 97232 ,  UNITED...
#
#          Business Name (PPP) Loan Amount Foregiveness Amount  \
# 0     (THE) PANDA RESTAURANT     17000.0             17153.7
# 1     (THE) PANDA RESTAURANT     18100.0            18247.28
# 2     (THE) PANDA RESTAURANT     25500.0            25710.99
# ...

# %%
ppp_yelp_allbiz_df = ppp_yelp_allbiz_df.drop_duplicates(
  subset = ['Address', 'Business Name (PPP)'],
  keep = 'first').reset_index(drop = True)
ppp_yelp_allbiz_df
# Out:
#                                                 Address  \
# 0     555 N MAIN ST. , PRINEVILLE, OR 97754 ,  UNITE...
# 1     2118 LANCASTER DRIVE NORTHEAST,SUITE 110 , SAL...
# 2     224 NORTHWEST 1ST AVENUE, OREGON , CANBY, OR 9...
# 3     3962 SE HAWTHORNE BLVD , PORTLAND, OR 97214 , ...
# 4     1412 13TH ST STE 300 , HOOD RIVER, OR 97031 , ...
# ...                                                 ...
# 7303  4066 MOOSE RUN DR SW , ALBANY, OR 97321 ,  UNI...
# 7304  16362 LOWER HARBOR ROAD , BROOKINGS, OR 97415 ...
# 7305  4835 N ALBINA AV , PORTLAND, OR 97217 ,  UNITE...
# 7306  1220 NW 6TH ST , GRANTS PASS, OR 97526 ,  UNIT...
# 7307  401 NE 28TH AVE , PORTLAND, OR 97232 ,  UNITED...
#
#          Business Name (PPP) Loan Amount Foregiveness Amount  \
# 0     (THE) PANDA RESTAURANT     17000.0             17153.7
# 1     (THE) PANDA RESTAURANT     18100.0            18247.28
# 2     (THE) PANDA RESTAURANT     25500.0            25710.99
# ...

# %%
count_open1 = ppp_yelp_allbiz_df[ppp_yelp_allbiz_df["Business Status"] == "Open"]
count_open1
# Out:
#                                                 Address Business Name (PPP)  \
# 3     3962 SE HAWTHORNE BLVD , PORTLAND, OR 97214 , ...        1-2-3 YO LLC
# 5     8610 SW HALL BLVD , BEAVERTON, OR 97008 ,  UNI...       11 BLOCKS LLC
# 9     8727 N LOMBARD ST , PORTLAND, OR 97203 ,  UNIT...     17TH EFFECT INC
# 10    147 E MAIN ST , KLAMATH FALLS, OR 97601 ,  UNI...           19AD4 LLC
# 12    600 SW 4TH AVE , PORTLAND, OR 97204 ,  UNITED ...   2 ANDY ENTERPRISE
# ...                                                 ...                 ...
# 7299  3988 W 12TH AVE , EUGENE, OR 97402 ,  UNITED S...         ZINGARO INC
# 7301  3970 MERCANTILE DR , LAKE OSWEGO, OR 97035 ,  ...            ZKL, LLC
# 7303  4066 MOOSE RUN DR SW , ALBANY, OR 97321 ,  UNI...           ZNE CORP.
# 7306  1220 NW 6TH ST , GRANTS PASS, OR 97526 ,  UNIT...            ZOOK LLC
# 7307  401 NE 28TH AVE , PORTLAND, OR 97232 ,  UNITED...        ZUM WHOL INC
#
# ...

# %%
output_data_file = "ppp_yelp_left_ppp.csv"
# Export the City_Data into a CSV.
ppp_yelp_left_ppp.to_csv(output_data_file, index=False)

# %%
output_data_file = "ppp_yelp_allbiz.csv"
# Export the City_Data into a CSV.
ppp_yelp_allbiz_df.to_csv(output_data_file, index=False)

# %%
# export final tables to pgadmin
from sqlalchemy import create_engine
from config import db_password

db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/or_ppp_food"
engine = create_engine(db_string)

ppp_yelp_allbiz_df.to_sql(name='PPP Yelp All Business Left', con=engine, index=False)
ppp_yelp_left_ppp.to_sql(name='PPP Yelp Left PPP', con=engine, index=False)
# Out:
# 731
